# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
1+1
# Out:
# 2

# %%
1*3
# Out:
# 3

# %%
1/2
# Out:
# 0.5

# %%
2**4
# Out:
# 16

# %%
2+3*5+5
# Out:
# 22

# %%
(2+3)*(5+5)
# Out:
# 50

# %%
4%2
# Out:
# 0

# %%
5%2
# Out:
# 1

# %%
 # To check even numbers
#outputs raminder after division

# %%
var = 2

# %%
var
# Out:
# 2

# %%
x = 2
y=3

# %%
x+y
# Out:
# 5

# %%
x = x+x

# %%
x
# Out:
# 4

# %%
x = x+x

# %%
x
# Out:
# 8

# %%
#var can't start with numbers

# %%
#STRINGS

# %%
'single quote'
# Out:
# 'single quote'

# %%
"this is a string "
# Out:
# 'this is a string '

# %%
"i can't go"
# Out:
# "i can't go"

# %%
x = 'hello'

# %%
x
# Out:
# 'hello'

# %%
print(x)
# Out:
# hello

# %%
num = 1
name = 'King John'

# %%
'My name is {} and my number is {}'.format(name,num)
# Out:
# 'My name is King John and my number is 1'

# %%
print('My name is {} and my number is {}'.format(name,num))
# Out:
# My name is King John and my number is 1

# %%
print('My name is {y} and my number is {z}'.format(y=name,z=num))
# Out:
# My name is King John and my number is 1

# %% [markdown]
# # INDEXING

# %%
s = 'hello'

# %%
s[0]
# Out:
# 'h'

# %%
s[4]
# Out:
# 'o'

# %%
hello_inverse = s[4]+s[3]+s[2]+s[1]+s[0]

# %%
print(hello_inverse)
# Out:
# olleh

# %% [markdown]
# ## SLICING

# %%
s = 'abcdefghijk'

# %%
s[0:] #starting at index 0, grab everything that follows
# Out:
# 'abcdefghijk'

# %%
s[:3] #grab everything upto but not including index 3
# Out:
# 'abc'

# %%
s[0:3]
# Out:
# 'abc'

# %%
s[3:6]
# Out:
# 'def'

# %% [markdown]
# # LISTS

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
['a','b','c']
# Out:
# ['a', 'b', 'c']

# %%
my_list = ['a','b','c']

# %%
print(my_list)
# Out:
# ['a', 'b', 'c']

# %%
my_list.append('d')

# %%
print(my_list)
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0]
# Out:
# 'a'

# %%
my_list[1:3]
# Out:
# ['b', 'c']

# %%
my_list[0] = 'NEW'

# %%
my_list
# Out:
# ['NEW', 'b', 'c', 'd']

# %%
nest = [1,2,[3,4]]

# %%
nest
# Out:
# [1, 2, [3, 4]]

# %%
nest[2]
# Out:
# [3, 4]

# %%
nest[2][0]
# Out:
# 3

# %%
nest[2][1]
# Out:
# 4

# %%
nest = [1,2,3,[4,5,['target']]]

# %%
nest[3][2][0]
# Out:
# 'target'
